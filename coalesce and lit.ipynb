# %%
colu = ["dep","date","sales","Price"]
data=[
    ("IT",None,"Bag",100),
    ("IT","02/24/2026",None,200),
    ("CSC","23/02/2026","Bag",None),
    (None,"23/02/2026","pen",100)
    ]

df=spark.createDataFrame(data, colu)
display(df)

# %%
df.printSchema()

# %%
from pyspark.sql.functions import lit, coalesce, col, to_date, try_to_date

# %%
dff=df.fillna({"dep": "NA", "Sales":"unkwonn","Price":0})
dff.display()

# %%
from pyspark.sql.functions import col, to_date, coalesce,lit



df2 = df.withColumn(
    "date",
    coalesce(
        to_date(col("date"), "dd/MM/yyyy"),
        to_date(col("date"), "MM/dd/yyyy"),
        lit("1900-01-01")
    )
)

display(df2)
