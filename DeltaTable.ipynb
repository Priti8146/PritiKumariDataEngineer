# %%
dfproduct=spark.read.format("csv").option("header",True).option("inferSchema",True).load("/Volumes/workspace/default/csv_inputdata/Productnew.csv")
dfproduct.display()

# %%
dfproduct.write.mode("overwrite").format("delta").saveAsTable("deltacatalog.deltaschema.deltatable18March")

# %%
df1=spark.sql("select * from deltacatalog.deltaschema.deltatable18March")
df1.display()

# %%
df2=spark.read.table("deltacatalog.deltaschema.deltatable18March")
df2.display()

# %%
df3=spark.read.format("delta").table("deltacatalog.deltaschema.deltatable18March")
df3.display()

# %%
# %sql
update deltacatalog.deltaschema.deltatable18March set product_id=0 where product_id=101

# %%
# %sql
delete from deltacatalog.deltaschema.deltatable18March where product_id=102

# %%
# %sql
describe table deltacatalog.deltaschema.deltatable18March

# %%
# %sql
describe history deltacatalog.deltaschema.deltatable18March

# %%
# %sql
describe detail deltacatalog.deltaschema.deltatable18March

# %%
# %sql
select * from deltacatalog.deltaschema.deltatable18March  VERSION AS OF 1

# %%
# %sql
select * from deltacatalog.deltaschema.deltatable18March  timestamp AS of '2026-03-18T11:22:38.000+00:00'

# %%
# %sql
VACUUM  deltacatalog.deltaschema.deltatable18March RETAIN 168 HOURS

# %%
spark.sql("VACUUM deltacatalog.deltaschema.deltatable18March RETAIN 170 HOURS")

# %%
# %sql
OPTIMIZE deltacatalog.deltaschema.deltatable18March

# %%
# %sql
OPTIMIZE deltacatalog.deltaschema.deltatable18March ZORDER BY (date)

# %%
# %sql
select * from deltacatalog.deltaschema.deltatable18March

# %%
dfpart18March=spark.read.format("delta").table("deltacatalog.deltaschema.deltatable18March")
dfpart18March.display()

# %%
dfpart18March.write.format("delta").mode("overwrite").partitionBy("date").saveAsTable("deltacatalog.deltaschema.deltapart")

# %%
dfpart18March.write.mode("overwrite").partitionBy("date").format("delta").save("/Volumes/workspace/default/delta19march")

# %%
# %sql
CONVERT TO DELTA parquet.`/Volumes/workspace/default/delta19march`
PARTITIONED BY (date STRING)

# %%
dfpart18March.write.option("mergeSchema", "true").format("delta").mode("append").saveAsTable("delta19march_append")

# %%
# Perform merge (upsert)
delta_table.alias("target").merge(
    df_new.alias("source"),
    "target.id = source.id"
).whenMatchedUpdateAll() \
 .whenNotMatchedInsertAll() \
 .execute()
