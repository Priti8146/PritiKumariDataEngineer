# %%
dbutils.fs.ls("/Volumes/workspace/default/workout_practise/Input/")

# %%
dbutils.notebook.run("/Workspace/Users/pritipuja@gmail.com/PritiKumariDataEngineer/drop columns",30)

# %%
dbutils.widgets.text("link","")
dbutils.widgets.text("time","")

# %%
link1=dbutils.widgets.get("link")
time1=dbutils.widgets.get("time")

# %%
dbutils.notebook.run(link1, int(time1))
